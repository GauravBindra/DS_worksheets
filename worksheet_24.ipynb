# %% [markdown]
# # Worksheet 24
#
# Name:  Gauravdeep Singh Bindra
# UID: U23346660
#
# ### Topics
#
# - Tuning Neural Networks
#
# ## Tuning Neural Networks
#
# Nothing to do in this worksheet except follow along in lecture / use this code to better understand Neural Networks.

# %%
import math as m
import numpy as np
import matplotlib.pyplot as plt
import sklearn.datasets as datasets
from tensorflow import keras, math, random, stack
from tensorflow.keras import layers, initializers
from tensorflow.keras.activations import relu

# Set random seed for reproducibility
np.random.seed(1)
random.set_seed(1)

# Data generation - don't modify
centers = [[0, 0]]
t, _ = datasets.make_blobs(n_samples=200, centers=centers, cluster_std=1,
                                random_state=1)

colors = np.array([x for x in 'bgrcmyk'])

# CURVE
def generate_curve_data(t):
    # create some space between the classes
    X = np.array(list(filter(lambda x : m.cos(4*x[0]) - x[1] < -.5 or m.cos(4*x[0]) - x[1] > .5, t)))
    Y = np.array([1 if m.cos(4*x[0]) - x[1] >= 0 else 0 for x in X])
    return X, Y

# The model - modify this
model = keras.models.Sequential()
model.add(layers.Dense(3, input_dim=2, activation="sigmoid"))
model.add(layers.Dense(1, activation="sigmoid"))
model.compile(loss="binary_crossentropy")

X, Y = generate_curve_data(t)

# plot the data
plt.scatter(X[:,0],X[:,1],color=colors[Y].tolist(), s=100, alpha=.9)
plt.show()

history = model.fit(X, Y, batch_size=50, epochs=200)

# Plot the decision boundary

# create a mesh to plot in
h = .02  # step size in the mesh
x_min, x_max = X[:, 0].min() - .5, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - .5, X[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                     np.arange(y_min, y_max, h))
meshData = np.c_[xx.ravel(), yy.ravel()]

fig, ax = plt.subplots()
Z = model.predict(meshData)
Z = np.array([0 if x < .5 else 1 for x in Z])
Z = Z.reshape(xx.shape)
ax.contourf(xx, yy, Z, alpha=.3, cmap=plt.cm.Paired)
ax.axis('off')

# Plot also the training points
ax.scatter(X[:, 0], X[:, 1], color=colors[Y].tolist(), s=100, alpha=.9)
plt.title("Decision Boundary")
plt.show()
# Out:
# 2023-12-07 17:17:31.127324: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Epoch 1/200
# 3/3 [==============================] - 1s 3ms/step - loss: 0.7345
# Epoch 2/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.7315
# Epoch 3/200
# 3/3 [==============================] - 0s 25ms/step - loss: 0.7295
# Epoch 4/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.7279
# Epoch 5/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.7263
# Epoch 6/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.7249
# Epoch 7/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.7236
# Epoch 8/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.7224
# Epoch 9/200
# 3/3 [==============================] - 0s 16ms/step - loss: 0.7211
# Epoch 10/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.7200
# Epoch 11/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.7187
# Epoch 12/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.7176
# Epoch 13/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.7164
# Epoch 14/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.7154
# Epoch 15/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.7144
# Epoch 16/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.7133
# Epoch 17/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.7122
# Epoch 18/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.7112
# Epoch 19/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.7100
# Epoch 20/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.7090
# Epoch 21/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.7079
# Epoch 22/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.7069
# Epoch 23/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.7059
# Epoch 24/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.7050
# Epoch 25/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.7039
# Epoch 26/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.7029
# Epoch 27/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.7018
# Epoch 28/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.7008
# Epoch 29/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6998
# Epoch 30/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6988
# Epoch 31/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6978
# Epoch 32/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6969
# Epoch 33/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.6959
# Epoch 34/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6950
# Epoch 35/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6940
# Epoch 36/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6931
# Epoch 37/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6921
# Epoch 38/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6912
# Epoch 39/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6902
# Epoch 40/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6892
# Epoch 41/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6883
# Epoch 42/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6873
# Epoch 43/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6864
# Epoch 44/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6854
# Epoch 45/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6845
# Epoch 46/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6836
# Epoch 47/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6826
# Epoch 48/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6817
# Epoch 49/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6807
# Epoch 50/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6798
# Epoch 51/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6789
# Epoch 52/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6780
# Epoch 53/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6772
# Epoch 54/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6763
# Epoch 55/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6755
# Epoch 56/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6746
# Epoch 57/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6737
# Epoch 58/200
# 3/3 [==============================] - 0s 11ms/step - loss: 0.6729
# Epoch 59/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6720
# Epoch 60/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6712
# Epoch 61/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6704
# Epoch 62/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6695
# Epoch 63/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6687
# Epoch 64/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6679
# Epoch 65/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6671
# Epoch 66/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6662
# Epoch 67/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6654
# Epoch 68/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6646
# Epoch 69/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6637
# Epoch 70/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6629
# Epoch 71/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6621
# Epoch 72/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6613
# Epoch 73/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6605
# Epoch 74/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6596
# Epoch 75/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6587
# Epoch 76/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6579
# Epoch 77/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6571
# Epoch 78/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6564
# Epoch 79/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6556
# Epoch 80/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6548
# Epoch 81/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6540
# Epoch 82/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.6531
# Epoch 83/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6523
# Epoch 84/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6515
# Epoch 85/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.6506
# Epoch 86/200
# 3/3 [==============================] - 0s 20ms/step - loss: 0.6498
# Epoch 87/200
# 3/3 [==============================] - 0s 10ms/step - loss: 0.6490
# Epoch 88/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.6483
# Epoch 89/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.6475
# Epoch 90/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6467
# Epoch 91/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6459
# Epoch 92/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6451
# Epoch 93/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6444
# Epoch 94/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6436
# Epoch 95/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6429
# Epoch 96/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6421
# Epoch 97/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6413
# Epoch 98/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6407
# Epoch 99/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6399
# Epoch 100/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6392
# Epoch 101/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6385
# Epoch 102/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6377
# Epoch 103/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6370
# Epoch 104/200
# 3/3 [==============================] - 0s 17ms/step - loss: 0.6363
# Epoch 105/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6356
# Epoch 106/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6349
# Epoch 107/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6342
# Epoch 108/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6334
# Epoch 109/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6327
# Epoch 110/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.6320
# Epoch 111/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6312
# Epoch 112/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6305
# Epoch 113/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6298
# Epoch 114/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6291
# Epoch 115/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.6284
# Epoch 116/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6277
# Epoch 117/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.6269
# Epoch 118/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6262
# Epoch 119/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6256
# Epoch 120/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6249
# Epoch 121/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6242
# Epoch 122/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6234
# Epoch 123/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6227
# Epoch 124/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6221
# Epoch 125/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6213
# Epoch 126/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6207
# Epoch 127/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6200
# Epoch 128/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6192
# Epoch 129/200
# 3/3 [==============================] - 0s 25ms/step - loss: 0.6186
# Epoch 130/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.6179
# Epoch 131/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6171
# Epoch 132/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6164
# Epoch 133/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6157
# Epoch 134/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6150
# Epoch 135/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6143
# Epoch 136/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6136
# Epoch 137/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6128
# Epoch 138/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6122
# Epoch 139/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6114
# Epoch 140/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6108
# Epoch 141/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6102
# Epoch 142/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6093
# Epoch 143/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6087
# Epoch 144/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6080
# Epoch 145/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6074
# Epoch 146/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6067
# Epoch 147/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6060
# Epoch 148/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6053
# Epoch 149/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6047
# Epoch 150/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6039
# Epoch 151/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6032
# Epoch 152/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6025
# Epoch 153/200
# 3/3 [==============================] - 0s 17ms/step - loss: 0.6018
# Epoch 154/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6010
# Epoch 155/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6003
# Epoch 156/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.5995
# Epoch 157/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.5988
# Epoch 158/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.5980
# Epoch 159/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.5973
# Epoch 160/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.5967
# Epoch 161/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.5958
# Epoch 162/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.5952
# Epoch 163/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.5944
# Epoch 164/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.5937
# Epoch 165/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.5930
# Epoch 166/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.5923
# Epoch 167/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.5916
# Epoch 168/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.5908
# Epoch 169/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.5900
# Epoch 170/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.5893
# Epoch 171/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.5886
# Epoch 172/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.5879
# Epoch 173/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.5871
# Epoch 174/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.5863
# Epoch 175/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.5856
# Epoch 176/200
# 3/3 [==============================] - 0s 20ms/step - loss: 0.5848
# Epoch 177/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.5840
# Epoch 178/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.5833
# Epoch 179/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.5825
# Epoch 180/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.5817
# Epoch 181/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.5810
# Epoch 182/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.5802
# Epoch 183/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.5794
# Epoch 184/200
# 3/3 [==============================] - 0s 17ms/step - loss: 0.5787
# Epoch 185/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.5779
# Epoch 186/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.5771
# Epoch 187/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.5763
# Epoch 188/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.5755
# Epoch 189/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.5747
# Epoch 190/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.5739
# Epoch 191/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.5731
# Epoch 192/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.5724
# Epoch 193/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.5715
# Epoch 194/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.5707
# Epoch 195/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.5700
# Epoch 196/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.5692
# Epoch 197/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.5684
# Epoch 198/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.5676
# Epoch 199/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.5668
# Epoch 200/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.5660
# 3602/3602 [==============================] - 4s 914us/step
